# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression

# %%
df = pd.read_table(r'C:\Users\Gateway\Desktop\projects_raw.txt')

# %%
df_interpolate=df.interpolate()
df_interpolate["blurb"].fillna( method ='ffill', inplace = True)
df_interpolate["country"].fillna( method ='ffill', inplace = True) 
df_interpolate["category"].fillna( method ='ffill', inplace = True)
df_interpolate["main_category"].fillna( method ='ffill', inplace = True)
df_interpolate["state"].fillna( method ='ffill', inplace = True)
df_interpolate.head(50)
# Out:
#             id                                               name  \
# 0   1295155228                         RMo Studio Needs Your Help
# 1     39027197  Animals on Ceramics, Hand Drawn and Handmade, ...
# 2       274865                                     Pots On Wheels
# 3    112491653                      Sarah Kersten Handmade Studio
# 4    330304757                             The Potter and the RAM
# 5    718228307                                 The Mobile Anagama
# 6    555147942  Zelda : Ocarina of Time replicas - complete oc...
# 7     29393977     Help us bring clay to life! Handmade ceramics.
# 8    139918796          Handmade ceramic pieces - Matope Cerámica
# 9   1442034305                                    Tandem Ceramics
# 10   308111597        Simone Bodmer-Turner : Clay Studio Buildout
# 11   987929668                                 Cardboard Ceramics
# 12    32942122                           Igniting Queen City Clay
# 13  1786261910                              Two Potters, One Kiln
# 14  2111009450  Cosmic Mugs: Art that Lets You Taste the Unive...
# 15    54132380                      AA Clay Studio For The People
# 16  1712275043  MMclay Ceramics Studio/Showroom: Bringing Art ...
# 17   424006467                                     Stuck in Italy
# 18  1395478013  MEMENTO MORI CUPS - A reminder to live life to...
# 19   474118794                           Bklyn Clay: Give Us Gas!
# 20    97374390                             Mason Hill Clay Studio
# 21   491446516                                 Krampus Beer Stein
# 22   883513654                          Pot Party Ceramics Studio
# 23   995319524             JUMPING CREEK POTTERY STUDIO EXPANSION
# 24  1091127776                   Make 100 Drippy Hanging Planters
# 25   979788806                           Carli - Ceramics - China
# 26  1357809583      Teorema Taller de Cerámica/ Ceramics Workshop
# 27    17767811    Purchasing a Raku kiln, equipment and materials
# 28    38323472     NIKO FAR WEST - Northwest Art & Ceramic Design
# 29   100108464  A-B PROJECTS: an exhibition space for expanded...
# 30  1545034574  The Clay Studio of Missoula Gallery Expansion ...
# 31   592049822         The Mud Room: A Community Ceramics Studio.
# 32   161196909              Erin Louise Clancy: Creating a Studio
# 33  1304586172                   Malka Dina: Handcrafted Ceramics
# 34  1751287458                           A Giant's Little Pottery
# 35  1348850422          Form & Fire: 6 Sculptures at Banff Centre
# 36   157948096     Brian Giniewski Ceramics: Made in Philadelphia
# 37   371921518                   R+R Ceramics: INSPIRED TABLEWARE
# 38   564683703                    Mobilizing Art: Pots On Wheels!
# 39  1573323477                               Mancuerna Cafetera ♥
# 40   685374482  Your Favorite Brown Sugar Saver / Essential Oi...
# 41  1155372108                  Make100: SKT Ceramics Caribou Mug
# 42   710268515                      Decker-Smith Pottery Returns!
# 43   102929114  Firecrafted Ceramics and Handmade Porcelain Je...
# 44   506473822          Rose de Heer Ceramics: New Studio Project
# 45   247020317                         CGCERAMICS – Gettin' Jiggy
# 46  1372180959                           Colaboración Nº1: ALUXES
# 47  1113000644               Felt + Fat : A Ceramic Design Studio
# goal              569
# pledged          3576
# country            23
# deadline         5061
# created_at       5083
# launched_at      5083
# backers_count     525
# fx_rate            14
# category            7
# main_category       1
# state               4
# dtype: int64

# %%
df_interpolate.duplicated().sum()
# Out:
# 0

# %%
df_interpolate.dtypes
# Out:
# id                 int64
# name              object
# blurb             object
# goal             float64
# pledged          float64
# country           object
# deadline         float64
# created_at       float64
# launched_at      float64
# backers_count    float64
# fx_rate          float64
# category          object
# main_category     object
# state             object
# dtype: object

# %%
pd.to_numeric(df_interpolate['goal'], errors='coerce')
# Out:
# 0        2500.0
# 1         120.0
# 2       20000.0
# 3       30000.0
# 4       16000.0
#          ...
# 5079     2220.0
# 5080      750.0
# 5081      150.0
# 5082     2000.0
# 5083     2000.0
# Name: goal, Length: 5084, dtype: float64

# %%
pd.to_numeric(df_interpolate['pledged'], errors='coerce')
# Out:
# 0        5504.0
# 1          38.0
# 2       25732.0
# 3       35083.0
# 4       22314.5
#          ...
# 5079     2525.0
# 5080     1146.0
# 5081      212.0
# 5082     2086.0
# 5083     2086.0
# Name: pledged, Length: 5084, dtype: float64

# %%
pd.to_numeric(df_interpolate['deadline'], errors='coerce')
# Out:
# 0       1.610129e+09
# 1       1.612505e+09
# 2       1.417496e+09
# 3       1.413574e+09
# 4       1.383424e+09
#             ...
# 5079    1.380654e+09
# 5080    1.290881e+09
# 5081    1.427796e+09
# 5082    1.370555e+09
# 5083    1.370555e+09
# Name: deadline, Length: 5084, dtype: float64

# %%
pd.to_numeric(df_interpolate['created_at'], errors='coerce')
# Out:
# 0       1.606933e+09
# 1       1.607542e+09
# 2       1.409351e+09
# 3       1.406328e+09
# 4       1.375916e+09
#             ...
# 5079    1.378024e+09
# 5080    1.288362e+09
# 5081    1.426676e+09
# 5082    1.365297e+09
# 5083    1.365297e+09
# Name: created_at, Length: 5084, dtype: float64

# %%
pd.to_numeric(df_interpolate['launched_at'], errors='coerce')
# Out:
# 0       1.607299e+09
# 1       1.609435e+09
# 2       1.415111e+09
# 3       1.410982e+09
# 4       1.380832e+09
#             ...
# 5079    1.379438e+09
# 5080    1.288458e+09
# 5081    1.426786e+09
# 5082    1.367963e+09
# 5083    1.367963e+09
# Name: launched_at, Length: 5084, dtype: float64

# %%
pd.to_numeric(df_interpolate['backers_count'], errors='coerce')
# Out:
# 0       152.0
# 1         3.0
# 2       278.0
# 3       233.0
# 4       273.0
#         ...
# 5079     28.0
# 5080     47.0
# 5081      5.0
# 5082     52.0
# 5083     52.0
# Name: backers_count, Length: 5084, dtype: float64

# %%
pd.to_numeric(df_interpolate['fx_rate'], errors='coerce')
# Out:
# 0       1.36147
# 1       1.00000
# 2       1.00000
# 3       1.00000
# 4       1.00000
#          ...
# 5079    1.36147
# 5080    1.00000
# 5081    1.22866
# 5082    1.00000
# 5083    1.00000
# Name: fx_rate, Length: 5084, dtype: float64

# %%
df_interpolate['backers_count'].plot.hist(bins=range(0, 2000, 1), edgecolor='green')
plt.xlabel('Backers_Count') 
plt.ylabel('Project_Count')
# Out:
# Text(0, 0.5, 'Project_Count')

# %%
df = df_interpolate.select_dtypes(exclude='object')
def missing_ratio(s):
    return s.isna().mean() * 100
def median(df):
    return df.quantile(0.5)
def lower_quartile(df):
    return df.quantile(0.25)
def upper_quartile(df):
    return df.quantile(0.75)
df.agg([missing_ratio, min, lower_quartile, median, upper_quartile, max])
# Out:
#                           id         goal      pledged      deadline  \
# missing_ratio   0.000000e+00         0.00        0.000  0.000000e+00
# min             4.658800e+04         0.01        0.000  1.241334e+09
# lower_quartile  5.325555e+08       550.00      483.900  1.405091e+09
# median          1.059642e+09      2000.00     1846.645  1.476715e+09
# upper_quartile  1.599577e+09      6000.00     5658.000  1.558899e+09
# max             2.147460e+09  50000000.00  8620552.000  1.614264e+09
#
#                   created_at   launched_at  backers_count   fx_rate
# missing_ratio   0.000000e+00  0.000000e+00            0.0  0.000000
# min             1.240601e+09  1.240603e+09            0.0  0.009694
# lower_quartile  1.397523e+09  1.402425e+09           12.0  1.000000
# median          1.469999e+09  1.474045e+09           36.0  1.000000
# upper_quartile  1.552992e+09  1.556214e+09           84.0  1.000000
# max             1.609369e+09  1.609435e+09        10648.0  1.361470

# %%
df=df_interpolate.select_dtypes(include='object')
def value_counts(col):
    return dict(col.value_counts())
df= df.agg([missing_ratio, pd.Series.nunique, value_counts])
df
# Out:
#                                                             name  \
# missing_ratio                                                  0
# nunique                                                     5081
# value_counts   {'FORBIDDEN': 2, 'Ceramics Studio': 2, 'My Her...
#
#                                                            blurb  \
# missing_ratio                                                  0
# nunique                                                     5056
# value_counts   {'imagine roaming the world’s largest ocean ye...
#
#                                                          country  \
# missing_ratio                                                  0
# nunique                                                       23
# value_counts   {'US': 3626, 'GB': 581, 'CA': 230, 'AU': 85, '...
#
#                                                         category  \
# missing_ratio                                                  0
# nunique                                                        7
# value_counts   {'Conceptual Art': 960, 'Digital Art': 852, 'I...
#
#                main_category  \
# missing_ratio              0
# nunique                    1
# value_counts   {'Art': 5084}
#
#                                                            state
# missing_ratio                                                  0
# nunique                                                        4
# value_counts   {'successful': 3899, 'failed': 990, 'live': 10...

# %%
bins = df_interpolate['backers_count'].quantile([0, 0.25, 0.5, 0.75, 1])
bins
# Out:
# 0.00        0.0
# 0.25       12.0
# 0.50       36.0
# 0.75       84.0
# 1.00    10648.0
# Name: backers_count, dtype: float64

# %%
backers_rank = pd.cut(df_interpolate['backers_count'], bins, right=False)
backers_rank
# Out:
# 0       [84.0, 10648.0)
# 1           [0.0, 12.0)
# 2       [84.0, 10648.0)
# 3       [84.0, 10648.0)
# 4       [84.0, 10648.0)
#              ...
# 5079       [12.0, 36.0)
# 5080       [36.0, 84.0)
# 5081        [0.0, 12.0)
# 5082       [36.0, 84.0)
# 5083       [36.0, 84.0)
# Name: backers_count, Length: 5084, dtype: category
# Categories (4, interval[float64]): [[0.0, 12.0) < [12.0, 36.0) < [36.0, 84.0) < [84.0, 10648.0)]

# %%
bins = df_interpolate['backers_count'].quantile([0, 0.25, 0.5, 0.75, 1])
bins.iloc[-1] += 0.05
bins
# Out:
# 0.00        0.00
# 0.25       12.00
# 0.50       36.00
# 0.75       84.00
# 1.00    10648.05
# Name: backers_count, dtype: float64

# %%
df_interpolate = df_interpolate.assign(BackersRank=backers_rank)
df_interpolate
# Out:
#               id                                               name  \
# 0     1295155228                         RMo Studio Needs Your Help
# 1       39027197  Animals on Ceramics, Hand Drawn and Handmade, ...
# 2         274865                                     Pots On Wheels
# 3      112491653                      Sarah Kersten Handmade Studio
# 4      330304757                             The Potter and the RAM
# ...          ...                                                ...
# 5079   729499237           An Exhibition of Painting 'MATTER101013'
# 5080  1382715548                   asheville to miami mural project
# 5081   946248030                               Custom pet portraits
# 5082  1849927461                   "ADKS" 1st solo gallery art show
# 5083   353571473          Painted Diamonds - 30 Ball Parks in 30 We
#
#                                                   blurb     goal  pledged  \
# 0     Help RMo Studio to buy a new kiln for ceramics...   2500.0   5504.0
# 1     Custom Hand Drawn Animals on Handmade Ceramic ...    120.0     38.0
# 2     We're creating a mobile outreach gallery of be...  20000.0  25732.0
# 3     Help build a studio space for Sarah Kersten Ha...  30000.0  35083.0
# 4     I make sturdy, high-fired porcelain tableware ...  16000.0  22314.5
# ...                                                 ...      ...      ...
# 5079  I've been invited to curate a group show of Pa...   2220.0   2525.0
# 5080  creating a mural , about american revolutionar...    750.0   1146.0
# 5081  I love painting these, and from the 1st till t...    150.0    212.0
# 5082  June 7th I'll be showing an entire new body of...   2000.0   2086.0
# 5083  June 7th I'll be showing an entire new body of...   2000.0   2086.0
#
#      country      deadline    created_at   launched_at  backers_count  \
# 0         GB  1.610129e+09  1.606933e+09  1.607299e+09          152.0
# 1         US  1.612505e+09  1.607542e+09  1.609435e+09            3.0
# 2         US  1.417496e+09  1.409351e+09  1.415111e+09          278.0
# 3         US  1.413574e+09  1.406328e+09  1.410982e+09          233.0
# 4         US  1.383424e+09  1.375916e+09  1.380832e+09          273.0
# ...      ...           ...           ...           ...            ...
# 5079      GB  1.380654e+09  1.378024e+09  1.379438e+09           28.0
# 5080      US  1.290881e+09  1.288362e+09  1.288458e+09           47.0
# 5081      NL  1.427796e+09  1.426676e+09  1.426786e+09            5.0
# 5082      US  1.370555e+09  1.365297e+09  1.367963e+09           52.0
# 5083      US  1.370555e+09  1.365297e+09  1.367963e+09           52.0
#
#       fx_rate  category main_category       state      BackersRank
# 0     1.36147  Ceramics           Art        live  [84.0, 10648.0)
# 1     1.00000  Ceramics           Art        live      [0.0, 12.0)
# 2     1.00000  Ceramics           Art  successful  [84.0, 10648.0)
# 3     1.00000  Ceramics           Art  successful  [84.0, 10648.0)
# 4     1.00000  Ceramics           Art  successful  [84.0, 10648.0)
# ...       ...       ...           ...         ...              ...
# 5079  1.36147  Painting           Art  successful     [12.0, 36.0)
# 5080  1.00000  Painting           Art  successful     [36.0, 84.0)
# 5081  1.22866  Painting           Art  successful      [0.0, 12.0)
# 5082  1.00000  Painting           Art  successful     [36.0, 84.0)
# 5083  1.00000  Painting           Art  successful     [36.0, 84.0)
#
# [5084 rows x 15 columns]

# %%
df_interpolate.groupby('BackersRank')['backers_count'].agg([min, median, max])
# Out:
#                   min  median     max
# BackersRank
# [0.0, 12.0)       0.0     3.0    11.0
# [12.0, 36.0)     12.0    22.0    35.0
# [36.0, 84.0)     36.0    54.0    83.0
# [84.0, 10648.0)  84.0   159.0  9090.0
